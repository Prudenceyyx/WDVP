# %%
import sqlite3
import matplotlib.pyplot as plt 
import pandas as pd           # Data Manipulation
import numpy as np            # Linear Algebra
import seaborn as sns         # Data Visualization
import plotly.graph_objs as go
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler  # For scaling dataset
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation #For clustering
from sklearn.mixture import GaussianMixture #For GMM clustering

# %%
# Connect to database
# conn = sqlite3.connect('example.db')

# %% [markdown]
# ## Data Overview

# %%
# Use pandas to query data
# sheet_name = "small countries are beautiful"
# sql = "SELECT * FROM `small countries are beautiful`"

# df = pd.read_sql_query(sql, conn)

# Transform df(Dataframe) to numeric dtype
df = pd.read_excel("Datasets_cleaned.xlsx", 0)
cols = df.columns
for i in cols[1:]:
    df[i]=pd.to_numeric(df[i],downcast='float', errors='coerce')

# Data Cleaning

## Clean columns
df = df.drop(columns=["happy_planet_index","world_happiness","education_expenditure"])

## Clean rows
df = df.dropna(thresh=len(df.columns)*0.7)

cols
# Out:
# Index(['indicator', 'population', 'gdp_per_cap', 'gdp ', 'gdp_growth',
#        'gdp_per_km2', 'land_area', 'population_density', 'total_foreign_born',
#        'per_foreign_born', 'population_living_abroad_diaspora',
#        'population_living_abroad', 'happy_planet_index', 'world_happiness',
#        'human_development_index', 'health_expenditure',
#        'education_expenditure',
#        'sustainable_economic_development_assessment(seda)', 'unemployment',
#        'political_stability&absence_of_violence', 'control_of_corruption',
#        'judicial_effectiveness_score', 'government_integrity_score',
#        'property_rights_score', 'tax_burden_score',
#        'overall_economic_freedom_score', 'financial_freedom_score'],
#       dtype='object')

# %%
df.describe()
# Out:
#         population  gdp_per_cap           gdp   gdp_growth   gdp_per_km2  \
# count       65.000    65.000000      65.000000   65.000000  6.500000e+01
# mean   1904615.375    42.698463   20792.064453    2.489231  3.721242e+06
# std    1577619.875    71.757240   24139.335938    3.424321  8.541287e+06
# min     100000.000     0.200000     651.900024  -12.200000  5.136568e+03
# 25%     500000.000     3.500000    5553.399902    1.100000  2.306045e+05
# 50%    1400000.000    18.400000   11840.200195    2.500000  8.128644e+05
# 75%    3000000.000    38.500000   25709.800781    4.300000  2.345120e+06
# max    4900000.000   329.200012  127659.601562   10.200000  5.474684e+07
#
#           land_area  population_density  total_foreign_born  per_foreign_born  \
# count  6.500000e+01           65.000000              64.000         64.000000
# mean   1.160119e+05          162.844879          247978.625         11.317187
# std    2.650003e+05          272.648712          527014.000         14.856024
# min    2.980000e+02            1.979741            2394.000          0.100000
# 25%    5.128000e+03           31.032791           14630.750          2.475000
# 50%    2.318000e+04           73.725876           65552.500          6.700000
# 75%    6.888300e+04          168.154678          191534.250         13.200000
# max    1.553556e+06         1454.433350         2866136.000         73.800003
#
#        population_living_abroad_diaspora           ...             \
# count                       6.400000e+01           ...
# mean                        2.742704e+05           ...
# std                         3.471396e+05           ...
# min                         2.844000e+03           ...
# 25%                         5.624650e+04           ...
# 50%                         1.262595e+05           ...
# 75%                         3.510650e+05           ...
# max                         1.650772e+06           ...
#
#        sustainable_economic_development_assessment(seda)  unemployment  \
# count                                          46.000000     64.000000
# mean                                           52.978260      9.025000
# std                                            23.223751      6.365308
# min                                           -64.500000      0.300000
# 25%                                            45.525000      4.975000
# 50%                                            54.950001      7.200000
# 75%                                            65.850000     11.425000
# max                                            83.699997     29.700001
#
#        political_stability&absence_of_violence  control_of_corruption  \
# count                                64.000000              64.000000
# mean                                 -0.101094              -0.025781
# std                                   0.930753               1.036323
# min                                  -2.780000              -1.830000
# 25%                                  -0.710000              -0.665000
# 50%                                   0.030000              -0.270000
# 75%                                   0.667500               0.750000
# max                                   1.190000               2.220000
#
#        judicial_effectiveness_score  government_integrity_score  \
# count                     65.000000                   65.000000
# mean                      45.795380                   41.392303
# std                       20.217083                   17.693417
# min                       10.000000                   17.700001
# 25%                       28.200001                   27.500000
# 50%                       44.500000                   36.799999
# 75%                       57.299999                   50.900002
# max                       93.400002                   89.800003
#
#        property_rights_score  tax_burden_score  \
# count              65.000000         65.000000
# mean               49.390770         74.407692
# std                19.547264         12.570182
# min                17.600000         41.400002
# 25%                35.500000         69.599998
# 50%                48.599998         76.099998
# 75%                62.099998         83.000000
# max                89.000000         99.900002
#
#        overall_economic_freedom_score  financial_freedom_score
# count                       65.000000                65.000000
# mean                        59.663078                50.153847
# std                         10.500901                19.644680
# min                         31.900000                10.000000
# 25%                         52.299999                40.000000
# 50%                         60.000000                50.000000
# 75%                         67.500000                60.000000
# max                         80.900002                90.000000
#
# [8 rows x 23 columns]

# %%
df
# Out:
#                            indicator  population  gdp_per_cap           gdp   \
# 0                            Albania   2900000.0    34.200001   11840.200195
# 1                            Armenia   3000000.0    25.799999    8621.000000
# 2                            Bahamas    400000.0     9.000000   24555.199219
# 4                           Barbados    300000.0     4.800000   17100.199219
# 6                             Bhutan    800000.0     6.500000    8227.400391
# 7             Bosnia and Herzegovina   3900000.0    42.200001   10957.500000
# 8                           Botswana   2200000.0    36.700001   17041.599609
# 9                  Brunei Darussalam    400000.0    32.500000   76884.000000
# 10                        Cabo Verde    500000.0     3.500000    6662.000000
# 11          Central African Republic   4900000.0     3.200000     651.900024
# 12                           Comoros    800000.0     1.300000    1529.199951
# 13                             Congo   4500000.0    29.799999    6676.100098
# 14                        Costa Rica   4900000.0    80.699997   16435.800781
# 15                           Croatia   4200000.0    95.099998   22795.300781
# 16                            Cyprus    800000.0    29.700001   34970.300781
# 17                          Djibouti   1000000.0     3.300000    3369.600098
# 18                          Dominica    100000.0     0.800000   11374.599609
# 19                 Equatorial Guinea    800000.0    31.700001   38639.101562
# 20                           Estonia   1300000.0    38.500000   29312.900391
# 21                          Eswatini   1100000.0    11.100000    9775.799805
# 22                              Fiji    900000.0     8.300000    9268.099609
# 23                             Gabon   1900000.0    35.900002   19056.500000
# 24                            Gambia   2100000.0     3.400000    1666.599976
# 25                           Georgia   3700000.0    37.200001   10043.799805
# 26                     Guinea-Bissau   1700000.0     2.900000    1729.900024
# 27                            Guyana    800000.0     6.000000    7872.899902
# 28                           Iceland    300000.0    16.500000   49135.601562
# 29                           Ireland   4700000.0   324.899994   69230.796875
# 30                           Jamaica   2800000.0    25.400000    8975.700195
# 31                          Kiribati    100000.0     0.200000    1823.300049
# ..                               ...         ...          ...            ...
# 16                                     0.42                   1.50
# 17                                     0.05                  -0.27
# 18                                     0.05                  -0.55
# 19                                     1.13                   1.57
# 20                                    -0.30                  -0.66
# 21                                    -0.38                  -0.52
# 22                                     1.03                   0.80
# 23                                    -0.41                  -0.53
# 24                                     1.19                   0.71
# 25                                     0.37                  -0.16
# 26                                    -0.92                  -0.11
# 27                                    -1.97                  -1.28
# 28                                     0.90                   0.84
# 29                                     0.17                  -1.29
# 30                                    -1.08                  -1.18
# 31                                     1.11                   1.92
# ..                                      ...                    ...
# 37                                     0.03                  -0.68
# 38                                    -2.30                  -1.42
# 39                                    -0.53                  -1.33
# 40                                     0.51                   0.47
# 41                                    -1.09                  -0.52
# 42                                     0.75                   0.19
# 43                                     0.69                   0.27
# 44                                     0.60                   0.78
# 45                                     1.02                   0.57
# 46                                     0.87                   2.19
# 47                                    -0.71                  -0.64
# 48                                     1.04                   0.65
# 49                                     0.16                  -0.74
# 50                                    -0.10                  -0.60
# 51                                    -1.42                  -0.54
# 52                                    -0.25                  -0.51
# 53                                    -0.15                  -1.83
# 54                                    -0.66                  -1.20
# 55                                     0.66                   1.24
# 56                                    -0.30                  -0.30
# 57                                    -1.69                  -0.56
# 58                                     0.79                   0.36
# 59                                     1.07                   2.22
# 60                                     0.21                   1.26
# 61                                    -0.09                  -0.81
# 62                                      NaN                    NaN
# 63                                    -0.37                   0.74
# 64                                     0.58                   1.84
# 65                                     0.09                  -0.23
# 66                                    -0.13                  -0.14
#
#     judicial_effectiveness_score  government_integrity_score  \
# 0                      28.200001                   26.200001
# 1                      25.400000                   39.900002
# 2                      35.200001                   29.000000
# 4                      25.400000                   18.900000
# 6                      44.500000                   32.599998
# 7                      47.400002                   40.500000
# 8                      93.400002                   77.400002
# 9                      80.900002                   73.500000
# 10                     36.799999                   39.900002
# 11                     53.500000                   50.900002
# 12                     55.099998                   51.799999
# 13                     32.599998                   21.200001
# 14                     54.400002                   53.799999
# 15                     57.299999                   42.000000
# 16                     69.500000                   70.900002
# 17                     53.500000                   34.700001
# 18                     31.299999                   30.200001
# 19                     51.599998                   50.900002
# 20                     11.400000                   23.100000
# 21                     43.700001                   28.400000
# 22                     54.700001                   56.599998
# 23                     55.500000                   31.400000
# 24                     57.099998                   45.400002
# 25                     42.500000                   38.200001
# 26                     47.099998                   31.799999
# 27                     21.700001                   26.200001
# 28                     52.000000                   42.799999
# 29                     24.500000                   17.700001
# 30                     29.400000                   23.400000
# 31                     77.099998                   78.300003
# ..                           ...                         ...
# 37                     28.200001                   27.500000
# 38                     23.900000                   27.299999
# 39                     28.200001                   24.600000
# 40                     57.799999                   51.799999
# 41                     44.200001                   36.599998
# 42                     56.500000                   40.500000
# 43                     10.000000                   38.099998
# 44                     56.700001                   41.299999
# 45                     57.900002                   51.099998
# 46                     83.599998                   84.099998
# 47                     13.800000                   29.000000
# 48                     69.199997                   49.900002
# 49                     23.100000                   26.200001
# 50                     23.299999                   30.200001
# 51                     52.500000                   32.200001
# 52                     35.400002                   25.200001
# 53                     17.600000                   26.200001
# 54                     13.800000                   23.400000
# 55                     83.900002                   75.699997
# 18                     50.0
# 19                     30.0
# 20                     40.0
# 21                     60.0
# 22                     70.0
# 23                     50.0
# 24                     50.0
# 25                     60.0
# 26                     40.0
# 27                     30.0
# 28                     60.0
# 29                     50.0
# 30                     50.0
# 31                     80.0
# ..                      ...
# 37                     30.0
# 38                     20.0
# 39                     30.0
# 40                     50.0
# 41                     50.0
# 42                     60.0
# 43                     10.0
# 44                     60.0
# 45                     80.0
# 46                     80.0
# 47                     50.0
# 48                     30.0
# 49                     40.0
# 50                     40.0
# 51                     50.0
# 52                     60.0
# 53                     30.0
# 54                     20.0
# 55                     80.0
# 56                     40.0
# 57                     20.0
# 58                     50.0
# 59                     80.0
# 60                     70.0
# 61                     40.0
# 62                     50.0
# 63                     60.0
# 64                     70.0
# 65                     60.0
# 66                     40.0
#
# [65 rows x 24 columns]

# %% [markdown]
# # Data Transform

# %% [markdown]
# ## Data Standarization

# %% [markdown]
# It turned out that normalization (linearly from 0 to 1) isn't good for a dataset like this for too many outliers.
# We switch to standarization

# %%
# Normalize the data except a few cols

# df_norm = df.copy()

# # Create a minimum and maximum processor object
# min_max_scaler = preprocessing.MinMaxScaler()

# # Create an object to transform the data to fit minmax processor
# df_norm[df_norm.columns[1:]] = min_max_scaler.fit_transform(df[df_norm.columns[1:]])


df_norm = df.copy()

# std = std.dropna(how='any')

df_norm[df_norm.columns[1:]] = preprocessing.scale(df_norm[df_norm.columns[1:]])

pd.options.display.float_format = '{:,.5f}'.format
df_norm.describe()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: DataConversionWarning:
#
# Data with input dtype float32 were all converted to float64 by the scale function.
#        population  gdp_per_cap     gdp   gdp_growth  gdp_per_km2  land_area  \
# count    65.00000     65.00000 65.00000    65.00000     65.00000   65.00000
# mean      0.00000     -0.00000 -0.00000    -0.00000      0.00000   -0.00000
# std       1.00778      1.00778  1.00778     1.00778      1.00778    1.00778
# min      -1.15279     -0.59686 -0.84082    -4.32306     -0.43846   -0.44005
# 25%      -0.89727     -0.55052 -0.63619    -0.40885     -0.41186   -0.42169
# 50%      -0.32235     -0.34126 -0.37373     0.00317     -0.34316   -0.35303
# 75%       0.69973     -0.05896  0.20531     0.53291     -0.16237   -0.17923
# max       1.91345      4.02372  4.46156     2.26929      6.02048    5.46691
#
#        population_density  total_foreign_born  per_foreign_born  \
# count            65.00000            64.00000          64.00000
# mean              0.00000            -0.00000          -0.00000
# std               1.00778             1.00791           1.00791
# min              -0.59460            -0.46968          -0.76103
# 25%              -0.48721            -0.44627          -0.59990
# 50%              -0.32941            -0.34889          -0.31325
# 75%               0.01963            -0.10795           0.12774
# max               4.77406             5.00718           4.23914
#
#        population_living_abroad_diaspora           ...             \
# count                           64.00000           ...
# mean                            -0.00000           ...
# std                              1.00791           ...
# min                             -0.78808           ...
# 25%                             -0.63302           ...
# 50%                             -0.42974           ...
# 75%                              0.22297           ...
# max                              3.99662           ...
#
#        sustainable_economic_development_assessment(seda)  unemployment  \
# count                                           46.00000      64.00000
# mean                                             0.00000       0.00000
# std                                              1.01105       1.00791
# min                                             -5.11444      -1.38155
# 25%                                             -0.32448      -0.64129
# 50%                                              0.08584      -0.28898
# 75%                                              0.56037       0.38002
# max                                              1.33748       3.27375
#
#        political_stability&absence_of_violence  control_of_corruption  \
# count                                 64.00000               64.00000
# mean                                  -0.00000                0.00000
# std                                    1.00791                1.00791
# min                                   -2.90097               -1.75474
# 25%                                   -0.65938               -0.62169
# 50%                                    0.14196               -0.23752
# 75%                                    0.83230                0.75451
# max                                    1.39811                2.18420
#
#        judicial_effectiveness_score  government_integrity_score  \
# count                      65.00000                    65.00000
# mean                       -0.00000                     0.00000
# std                         1.00778                     1.00778
# min                        -1.78433                    -1.34947
# 25%                        -0.87710                    -0.79128
# 50%                        -0.06457                    -0.26157
# 75%                         0.57348                     0.54154
# max                         2.37300                     2.75721
#
#        property_rights_score  tax_burden_score  \
# count               65.00000          65.00000
# mean                 0.00000          -0.00000
# std                  1.00778           1.00778
# min                 -1.63901          -2.64631
# 25%                 -0.71615          -0.38544
# 50%                 -0.04077           0.13568
# 75%                  0.65524           0.68887
# max                  2.04210           2.04378
#
#        overall_economic_freedom_score  financial_freedom_score
# count                        65.00000                 65.00000
# mean                         -0.00000                  0.00000
# std                           1.00778                  1.00778
# min                          -2.66445                 -2.05991
# 25%                          -0.70664                 -0.52090
# 50%                           0.03233                 -0.00789
# 75%                           0.75212                  0.50511
# max                           2.03813                  2.04413
#
# [8 rows x 23 columns]

# %% [markdown]
# ## Data Visualization for overview

# %%
# Subset the data to key cols
# Visualize correlation in a heapmap

cols_name = df_norm.columns
df_corr = df_norm[cols_name]
cor = df_corr[1:].corr()

# Color palette
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.heatmap(cor, square = True, linewidths = 1,
           cmap = cmap)

# %%
#K means Clustering

df_kmeans = df_norm.dropna(axis='index', how='any')

# print(df_kmeans.head())


def doKmeans(X, nclust=2):
    model = KMeans(nclust)
    model.fit(X)
    clust_labels = model.predict(X)
    cent = model.cluster_centers_
    return (clust_labels, cent)


# print(np.any(np.isnan(df_kmeans)))
# print(np.all(np.isfinite(df_kmeans)))

sample = df_kmeans[df_kmeans.columns[1:]]
# print(sample)
clust_labels, cent = doKmeans(sample, 4)
kmeans = pd.DataFrame(clust_labels)
sample.insert((sample.shape[1]),'kmeans',kmeans)

fig = plt.figure()
ax = fig.add_subplot(111)
axis1 = cols_name[1]
axis2 = cols_name[2]
print(axis1, axis2)
scatter = ax.scatter(sample[axis1],sample[axis2],
                     c=kmeans[0],s=50)
ax.set_title('K-Means Clustering')
ax.set_xlabel(axis1)
ax.set_ylabel(axis2)
plt.colorbar(scatter)
# Out:
# population gdp_per_cap

# %%
#choropleth-maps
#Ref: https://plot.ly/python/choropleth-maps/
import plotly.plotly as py #For World Map
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

axis = cols_name[2] #'gdp_per_capita'
# axis = 'population'

data = dict(type = 'choropleth', 
           locations = df_norm['indicator'],
           locationmode = 'country names',
           z = df_norm[axis], 
           text = df_norm['indicator'],
           colorbar = {'title':axis},
           marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) )
           )

scope = 'globe'
# scope = 'asia'

layout = dict(title = axis2, 
             geo = dict(scope=scope,
                        showframe = False, 
                       projection = {'type': 'Mercator'}))

choromap3 = go.Figure(data = [data], layout=layout)

iplot(choromap3)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id
zealand", "Oman", "Panama", "Qatar", "Saint Lucia", "Saint Vincent and the Grenadines", "Samoa", "Sao Tome", "Seychelles", "Slovenia", "Solomon Islands", "Suriname", "Timor-Leste", "Tonga", "Trinidad and Tobago", "Uruguay", "Vanuatu"], "colorbar": {"title": "gdp_per_cap"}, "marker": {"line": {"color": "rgb(180,180,180)", "width": 0.5}}}], {"title": "gdp_per_cap", "geo": {"scope": "globe", "showframe": false, "projection": {"type": "Mercator"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# pp = sns.pairplot(df_kmeans[cols_name], height=1.8, aspect=1.8,
#                   plot_kws=dict(edgecolor="k", linewidth=0.5),
#                   diag_kind="kde", diag_kws=dict(shade=True))

# fig = pp.fig 
# fig.subplots_adjust(top=0.93, wspace=0.3)
# t = fig.suptitle('small countries', fontsize=14)
# t

# %% [markdown]
# ## Add Continent Column to valid data

# %%
import country_converter as converter

countries = list(df_norm.indicator.values)

df_norm['continent'] = converter.convert(names=countries, to='continent') 

# df_norm['continent']

# %%
df_norm[cols_name[1:]].loc[0].values
# print(cols[1:])
# Out:
# array([ 0.63585082, -0.11935518, -0.37372741, -0.29113191, -0.29178519,
#        -0.33699407, -0.21428809, -0.36406527, -0.55749416,  2.46398993,
#         1.29700745,  0.48616003, -0.35585942,  0.00529987, -0.08313034,
#        -2.90096556, -1.45324533, -0.87709562, -0.86532397, -1.6235437 ,
#         1.39438407, -0.8026131 , -2.059913  ])

# %% [markdown]
# ## Overview for all nations

# %%
# import plotly.plotly as py
# import plotly.graph_objs as go

data = []
color = "rgba(255,255,255,0)"

for i in range(len(df_norm)):
    data.append(go.Scatterpolar(
        name = df_norm['indicator'].iloc[i],
        mode = "lines",
#         fill = "toself",
#         fillcolor = "rgba(180,120,150,0.1)",
#         mode = "markers",
#         marker = dict(
#             color = "rgba(180,120,150,0.4)",
            
#         ),
        r = df_norm[cols_name[1:]].iloc[i].values,
        theta = cols_name[1:],
        line = dict(
            shape = "spline",
            color = "rgba(180,120,150,0.3)",
        )
    ))


layout = go.Layout(
    showlegend = False,
    polar=dict(
        angularaxis=dict(
            tickfont = dict(
                size = 8
                
            ),
            ticks = "outside" ,
            rotation = 90,
            direction = "clockwise"
        ),
        radialaxis=dict(
            visible=True,
            nticks=4,
            range = [-3,3]
        )
    )
)

fig = go.Figure(data=data, layout=layout)
fig['layout'].update(width=800,height=800)
iplot(fig)
# Out:
# <div id="832219f0-b189-481e-9902-ed7d2e1e1f0d" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("832219f0-b189-481e-9902-ed7d2e1e1f0d", [{"type": "scatterpolar", "name": "Albania", "mode": "lines", "r": [0.6358508171627806, -0.11935518015393246, -0.3737274099299876, -0.2911319123330611, -0.29178518649792234, -0.33699406712112046, -0.214288085532242, -0.3640652662794119, -0.5574941575761089, 2.463989932994942, 1.2970074516810357, 0.48616003049768747, -0.35585941912017033, 0.005299866021627912, -0.0831303425155217, -2.900965564552665, -1.453245329080186, -0.8770956195887272, -0.8653239650722193, -1.6235437024571364, 1.394384069228972, -0.8026131028264678, -2.05991299809868], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score", "financial_freedom_score"], "line": {"shape": "spline", "color": "rgba(180,120,150,0.3)"}}, {"type": "scatterpolar", "name": "Armenia", "mode": "lines", "r": [0.6997307292425036, -0.23732756355506343, -0.5081243455274405, 0.03259949811345928, -0.33113113814559536, -0.3339326941256482, -0.2214571594089517, -0.10859006222923304, -0.048657478282505884, 1.9250761071968647, 0.9073826120140627, 0.25764896050486547, -0.27182203035076363, -0.05564927828032171, 1.1519490395849157, 0.5426303182970258, -0.38340875171615846, -1.0166702249533857, -0.08499884041451294, 0.2427898617943976, 0.8572283217369381, 0.464204471159992, 1.018117918600497], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score", "financial_freedom_score"], "line": {"shape": "spline", "color": "rgba(180,120,150,0.3)"}}, {"type": "scatterpolar", "name": "Bahamas", "mode": "lines", "r": [-0.9611469848302927, -0.47327227678246275, 0.15710534392076209, 0.3563309787268793, -0.33298303499001203, -0.4031197238233212, -0.4559281473893844, -0.3608331701680444, 0.3380582957515901, -0.6799184252464612, -0.4112770341341412, 0.653734300614156, 0.35730190759268465, 0.3231067708848694, 0.34439714751987227, -0.9301025058119401, -0.5681987336557265, -0.5281592487935046, -0.7058415101798619, -1.1131375654887967, -0.032685693759163074, -1.4360217067694987, -1.0339026925322876], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score", "financial_freedom_score"], "line": {"shape": "spline", "color": "rgba(180,120,150,0.3)"}}, {"type": "scatterpolar", "name": "Barbados", "mode": "lines", "r": [-1.0250268969100156, -0.5322584550893126, -0.1541300 ...

# %%
df_sorted = df_norm.sort_values(by=['continent', 'indicator'])

## Access row using .iloc[]
# df_sorted.iloc[0]

# %%
## Polar Chart for each Continent

# data = []
# color = "rgba(255,255,255,0)"

# for i in range(len(df_norm)):
#     data.append(go.Scatterpolar(
#         name = df_norm['indicator'].iloc[i],
#         mode = "lines",
#         fill = "toself",
#         fillcolor = "rgba(180,120,150,0.1)",
#         r = df_norm[cols_name[1:]].iloc[i].values,
#         theta = cols_name[1:],
#         marker = dict(
#             color = color,
#         ),
#         line = dict(
#             shape = "spline",
#             color = color,
#         )
#     ))


# data.append(go.Scatterpolar(
#       name = "radial categories",
#       r = ["a", "b", "c", "d", "b", "f", "a"],
#       theta = [1, 4, 2, 1.5, 1.5, 6, 5],
#       thetaunit = "radians",
#       fill = "toself",
#       subplot = "polar2"
#     ))
    
# layout = go.Layout(
#     showlegend = False,
#     polar=dict(
#         domain = dict(
#             x = [0, 0.46],
#             y = [0.56, 1]
#         ),
#         angularaxis=dict(
#             tickfont = dict(
#                 size = 8
                
#             ),
#             ticks = "outside" ,
#             rotation = 90,
#             direction = "clockwise"
#         ),
#         radialaxis=dict(
#             visible=True,
#             nticks=4,
#             range = [0, 1.2]
#         )
#     ),
#     polar2 = dict(
#       domain = dict(
#         x = [0, 0.46],
#         y = [0, 0.44]
#       ),
#       radialaxis = dict(
#         angle = 180,
#         tickangle = -180
#       )
#     )
# )

# fig = go.Figure(data=data, layout=layout)
# iplot(fig)

# %% [markdown]
# ## Overview for each continent

# %%
from plotly import tools
from random import randint

total= df_norm['continent'].nunique()


traces = []
subplot_titles = []


# Plot one subplot 
def draw_one_nation(data, subplot):

    
    return go.Scatterpolar(
            name = data[0], # country name
            subplot = subplot,
            r = data[1:-2],
            theta = df_norm.columns[1:-2],
            mode = "lines",
#             fill = "toself",
#             fillcolor = "rgba(180,120,150,0.2)",
            line = dict(
                shape = "spline",
                color = "rgba(180,120,150,0.4)",
            ) 
#         mode = "markers",
#         marker = dict(
#             color = "rgba(180,120,150,0.4)",
            
#         )
    )
    

# Plot for group of continents
continents = df_norm.groupby('continent')
# continents.groups['Africa']
data = []
    
for i, continent in enumerate(continents):
    nations = continent[1] #df

    subplot = "polar"
    if i != 0:
        subplot += str(i+1)
    
    for i in range(len(nations)):
        nation = nations.iloc[i]
#         print(nation[0])
        data.append(draw_one_nation(nation, subplot))
    

    
# Subplot format
total = 5
cols = 1
rows = total//cols+1


width = 1/cols*0.8
height = 1/rows*0.8

w_offset = 1/cols*0.2
h_offset = 1/rows*0.2

polars = dict()
for i, continent in enumerate(continents):
    subplot = "polar"

    if i!=0:
        subplot += str(i+1)
        
    col = i % cols
    row = i // cols

    x = [(width+w_offset)*(col), width*(col+1) + w_offset*col]
    y = [1-height*(row+1)-h_offset*row, 1-(height+h_offset)*(row)]
        
    print(continent[0], col, row)

    
    polars[subplot] = dict(
        domain = dict(
            x = x,
            y = y
        ),
        angularaxis=dict(
            tickfont = dict(
                size = 8 
            ),
            ticks = "outside" ,
            rotation = 90,
            direction = "clockwise"
        ),
        radialaxis = dict(
            visible = True,
            tickfont = dict(
                size = 6 
            ),
            nticks = 6,
            range = [3, -2]
        )
    )

    
layout = go.Layout(
    showlegend = False,
    title = "Small Nation in different Continents ",
)


fig = go.Figure(data=data, layout=layout)
fig['layout'].update(polars)
fig['layout'].update(width=max(cols*500,800),height=rows*500)
iplot(fig)
# Out:
# Africa 0 0
# America 0 1
# Asia 0 2
# Europe 0 3
# Oceania 0 4
# <div id="66e759dd-3d40-4ce4-8dec-6585548a8492" style="height: 3000px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("66e759dd-3d40-4ce4-8dec-6585548a8492", [{"type": "scatterpolar", "name": "Botswana", "subplot": "polar", "r": [0.1886914326047201, -0.08424435813869854, -0.1565765340427776, 0.0031693954062845626, -0.4314267974652045, 1.7140573867845226, -0.586971692703689, -0.16702597742617586, -0.2793301303843248, -0.6269274051310547, -1.0398228359102368, -0.031798001343837846, -0.20474631637885185, -0.3865167022030159, -0.5264922455555485, 1.084076183410646, 1.7757159297156175, 2.372997472134964, 2.050927476744723, 1.511071748098877, -0.9145825871037558, 2.0381293912795932], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score"], "mode": "lines", "line": {"shape": "spline", "color": "rgba(180,120,150,0.4)"}}, {"type": "scatterpolar", "name": "Cabo Verde", "subplot": "polar", "r": [-0.8972670727505697, -0.5505160852159773, -0.5899097521072423, -0.4088524284121094, -0.336671453171948, -0.42584994294622514, -0.1007777491510052, -0.4457129865081104, -0.5642786397318182, -0.3151366163461641, 0.9349503386531386, -0.5116709305215988, -0.7135965603036998, null, -0.6214983460629608, -0.713524159766492, -0.8307949673356989, -0.44840244010240343, -0.08499884041451294, 0.21701177307543493, 1.0496423117092006, 0.4450105594832442], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score"], "mode": "lines", "line": {"shape": "spline", "color": "rgba(180,120,150,0.4)"}}, {"type": "scatterpolar", "name": "Central African Republic", "subplot": "polar", "r": [1.9134490587572393, -0.5547293831881196, -0.8408227026373866, -0.5854332200724067, -0.43846143777355395, 1.927988413476816, -0.5742748573480835, -0.31820010122449177, -0.5710631218875275, 0.4833522015267348, -0.5197103960514807, -2.697757684863639, -0.9279304509265902, -1.605501498087375, 0.9936056645793566, 1.1923653887060603, 1.162991345815543, 0.38406008254010254, 0.5415395459521963, -0.14903700806535122, 1.7711943153547767, 0.34903917059751416], "theta": ["population", "gdp_per_cap", "gdp ", "gdp_growth", "gdp_per_km2", "land_area", "population_density", "total_foreign_born", "per_foreign_born", "population_living_abroad_diaspora", "population_living_abroad", "human_development_index", "health_expenditure", "sustainable_economic_development_assessment(seda)", "unemployment", "political_stability&absence_of_violence", "control_of_corruption", "judicial_effectiveness_score", "government_integrity_score", "property_rights_score", "tax_burden_score", "overall_economic_freedom_score"], "mode": "lines", "line": {"shape": "spline", "color": "rgba(180,120,150,0.4)"}}, {"type": "scatterpolar", "name": "Comoros", "subplot": "polar", "r": [-0.705627336511401, -0.5814136092590689, -0.8041967040655039, 0.20918032485720645, -0.37043825649862977, -0.4326876431274166, 1.0146512 ...
